# %% [markdown]
# ### 뒤집힌 문자열

# %%
a = 'taehee'
a[::-1]
# Out:
# 'eeheat'

# %% [markdown]
# #### 제출 답안

# %%
# 제출 답안
def solution(my_string):
    return my_string[::-1]

# %%
print(solution("jaron"))
print(solution("bread"))
# Out:
# noraj
# daerb
