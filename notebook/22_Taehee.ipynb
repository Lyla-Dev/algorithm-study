# %% [markdown]
# ### 직각삼각형 출력하기

# %%
print('*' * 3)
# Out:
# ***

# %% [markdown]
# #### 제출 답안

# %%
n = int(input())

for i in range(1, n+1):
    print('*' * i)
# Out:
# *
# **
# ***
# ****
# *****
