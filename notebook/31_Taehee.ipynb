# %%
arr = [30, 10, 23, 6, 100]

# %%
min(arr)
# Out:
# 6

# %%
arr.index(min(arr))
# Out:
# 3

# %%
arr.pop(arr.index(min(arr)))
# Out:
# 6

# %%
arr
# Out:
# [30, 10, 23, 100]

# %%
sorted_arr = sorted(arr)
print(sorted_arr)
# Out:
# [10, 23, 30, 100]

# %%
arr.index(sorted_arr[3])
# Out:
# 3
